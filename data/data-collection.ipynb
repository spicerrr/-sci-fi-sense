# %% [markdown]
# ## Этап 1: Сбор данных

# %% [markdown]
# ### Оптимизированный процесс сбора сырых данных TMDB
#
# 1. **Параллельная загрузка**
#    - 20 одновременных потоков
#    - Обработка 750 страниц (рассчитанный лимит согласно ограничениям проекта)
#    - Автоматический пропуск пустых страниц
#
# 2. **Детализация информации**
#
#    Для каждого фильма получаем 26 колонок со свойствами:
#    > `id` `title` `original_title` `overview` `release_date` `popularity` `imdb_average` `imdb_count` `imdb_id` `director` `runtime` `tagline` `production_countries` `original_language` `production_companies` `genres` `full_cast` `top_cast` `secondary_cast` `episodic_cast`
#
# 3. **Контроль качества**
#    ```python
#    response.raise_for_status()  # проверка HTTP-ошибок
#    if not data.get('results'):  # пропуск пустых страниц
#    ```
#
# **Защитные механизмы**
# - Пауза `0.1 сек` между запросами
# - Повторная попытка при сбоях
# - Логирование всех ошибок
#
#
# **Особенности:**
# - Автоматическое создание папки `data/raw`
# - Сохранение в CSV с кодировкой UTF-8
# - Вывод базовой статистики после завершения
#
#
# > **Производительность**: На тестах сбор 10,000 записей занимает ~5 минут при стабильном интернет-соединении.

# %%
import requests
import pandas as pd
import time
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# - узнав id жанра Sci-Fi в документации TMDB, собираем данные о научно-фантастических фильмах с TMDB
# - `total_pages:` устанавливаем, сколько страниц страниц парсить (на каждой до 20 фильмов)

# %% [markdown]
# `fetch_movies_page` - функция для получения данных о фильмах с одной страницы API TMDB.
#
# - делает GET-запрос к TMDB API для получения списка фильмов по жанру
# - обрабатывает возможные ошибки запроса
#   - проверяет HTTP статус через `raise_for_status()`
#   - ловит исключения и логирует ошибки
#   - возвращает пустой DataFrame при проблемах
# - конвертирует JSON-ответ в pandas DataFrame

# %% [markdown]
# `get_movie_details` -- функция дополняет базовую информацию о фильмах новыми колонками.
#
# **роли функции:**
# - **принимает** на вход dataframe с минимальными данными о фильмах (id, название и т.д.)
# - **возвращает** новый dataframe с расширенной информацией
#
# **что делает внутри:**
# 1. для каждого фильма в цикле:
#    - строит url запроса к api, включая:
#      - id фильма
#      - api-ключ
#      - дополнительные данные (credits — актёры, external_ids — imdb)
#    - обрабатывает возможные ошибки запроса
# 2. на базе каждой строки присваивает значения в новых колонках:
#
# | **Колонка**                | **Тип данных** | **Описание**                                                                 | **Источник**                     |
# |----------------------------|----------------|------------------------------------------------------------------------------|----------------------------------|
# | **id**                     | int            | Уникальный ID фильма в TMDB                                                   | Базовый запрос                   |
# | **title**                  | str            | Локализованное название                                                       | Базовый запрос                   |
# | **original_title**         | str            | Оригинальное название                                                         | Базовый запрос                   |
# | **overview**               | str            | Описание сюжета                                                               | Базовый запрос                   |
# | **release_date**           | str            | Дата выхода (YYYY-MM-DD)                                                      | Базовый запрос                   |
# | **popularity**             | float          | Индекс популярности TMDB                                                      | Базовый запрос                   |
# | **imdb_average**           | float          | Средний рейтинг IMDb (0-10)                                                   | `vote_average` из базовых        |
# | **imdb_count**             | int            | Количество оценок IMDb                                                        | `vote_count` из базовых          |
# | **imdb_count**             | int            | Количество оценок IMDb                                                        | `external_ids`         |
# | **director**               | list[str]      | Режиссёр фильма                                                              | `credits.crew` (job == 'Director')|
# | **producer**               | list[str]      | Продюсеры фильма                                                              | `credits.crew` (job == 'Producer')|
# | **writer**                 | list[str]      | Сценаристы фильма                                                             | `credits.crew` (job == 'Writer')|
# | **editor**                 | list[str]      | Монтажеры фильма                                                              | `credits.crew` (job == 'Editor') |
# | **cinematographer**        | list[str]      | Операторы (фотооператоры)                                                     | `credits.crew` (job == 'Director of Photography') |
# | **budget**                 | int            | Бюджет фильма ($)                                                             | Детальный запрос                 |
# | **revenue**                | int            | Сборы фильма ($)                                                              | Детальный запрос                 |
# | **runtime**                | int            | Длительность фильма в минутах                                                 | Детальный запрос                 |
# | **tagline**                | str            | Слоган фильма                                                                 | Детальный запрос                 |
# | **production_countries**   | list[str]      | Страны производства (например ["US", "UK"])                                    | Детальный запрос                 |
# | **original_language**      | str            | Язык оригинала (код ISO 639-1)                                                | Детальный запрос                 |
# | **production_companies**   | list[str]      | Компании-производители                                                        | Детальный запрос                 |
# | **imdb_id**                | str            | ID фильма на IMDb (например "tt1234567")                                      | `external_ids`                   |
# | **genres**                 | list[str]      | Жанры фильма (например ["Sci-Fi", "Adventure"])                               | Детальный запрос                 |
# | **full_cast**              | list[str]      | Весь актёрский состав                                                         | `credits.cast`                   |
# | **top_cast**               | list[str]      | 5 главных актёров                                                            | `credits.cast[:5]`               |
# | **secondary_cast**         | list[str]      | Актеры на второстепенных ролях (5-15 в списке)                                | `credits.cast[5:15]`             |
# | **episodic_cast**          | list[str]      | Эпизодические роли (актёры после 15-го места)                                 | `credits.cast[15:]`              |
#
#
# 1. **Детальные запросы**:
#    - самые простые для вызова поля, такие как `budget`, `revenue`, `runtime`, `tagline`, `genres` и другие, извлекаются из детализированных запросов
# 2. **`director`**, **`producer`**, **`writer`**, **`editor`**, **`cinematographer`**:
#    - эти колонки извлекаются из поля `crew` в `credits`, где каждый человек имеет роль, указанную в поле `job`.
#    - в каждой из этих колонок будут храниться имена людей, занимающихся соответствующими ролями.
#
# 3. **`full_cast`**, **`top_cast`**, **`secondary_cast`**, **`episodic_cast`**:
#    - Эти данные извлекаются из поля `cast` в `credits` и представляют собой список актеров. В `full_cast` будет весь актерский состав, в `top_cast` — первые 5 актеров, в `secondary_cast` — актеры с 6 по 15, а в `episodic_cast` — актеры с 16-го места и дальше.
#
# 4. **`production_companies`**, **`production_countries`**:
#    - Эти данные извлекаются из поля `production_companies` и `production_countries` в детальном запросе фильма. Они содержат названия компаний и стран, участвующих в производстве фильма.

# %%
api_key = 'bcd3dc372c98663f3b351a83592efe6a'

def get_sci_fi_movies(total_pages=750): 
    # id жанра научной фантастики в TMDB
    sci_fi_genre_id = 878

    # здесь будем хранить все собранные данные
    all_movies = pd.DataFrame()
    
    # используем многопоточность для ускорения
    with ThreadPoolExecutor(max_workers=20) as executor:
        # создаем задачи для каждой страницы
        tasks = {
            executor.submit(fetch_movies_page, page, sci_fi_genre_id): page 
            for page in range(1, total_pages + 1)
        }
        
        # обрабатываем результаты по мере готовности
        for future in as_completed(tasks):
            page_data = future.result()
            if not page_data.empty:
                all_movies = pd.concat([all_movies, page_data], ignore_index=True)
            
            # небольшая пауза, чтобы не нагружать API
            time.sleep(0.1)
    
    return all_movies

def fetch_movies_page(page, genre_id):
    url = f'https://api.themoviedb.org/3/discover/movie?api_key={api_key}&with_genres={genre_id}&page={page}'
    
    try:
        response = requests.get(url)
        response.raise_for_status()  # проверяем на ошибки HTTP
        data = response.json()
        
        # если на странице нет фильмов, возвращаем пустой датафрейм
        if not data.get('results'):
            return pd.DataFrame()
        
        page_df = pd.DataFrame(data['results'])
        return get_movie_details(page_df)
    
    except Exception as e:
        print(f"проблема со страницей {page}: {e}")
        return pd.DataFrame()

def get_movie_details(movies_df):
    detailed_movies = []
    
    for _, movie in movies_df.iterrows():
        try:
            # запрашиваем детали для каждого фильма
            detail_url = f'https://api.themoviedb.org/3/movie/{movie["id"]}?api_key={api_key}&append_to_response=credits,external_ids'
            detail_response = requests.get(detail_url)
            detail_response.raise_for_status()
            details = detail_response.json()
            
            # формируем полную запись о фильме
            movie_data = {
                'id': movie['id'],
                'title': movie['title'],
                'original_title': movie['original_title'],
                'overview': movie['overview'],
                'release_date': movie['release_date'],
                'popularity': movie['popularity'],
                'imdb_average': movie['vote_average'], # рейтинг imdb для фильма или сериала
                'imdb_count': movie['vote_count'], # количество голосов на imdb
                'imdb_id': details.get('external_ids', {}).get('imdb_id', None),

                # фильтрация и извлечение ролей съемочной команды из списка объектов
                'director': [ person['name'] for person in details.get('credits', {}).get('crew', []) if person['job'] == 'Director'], # режиссер
                'producer': [person['name'] for person in details.get('credits', {}).get('crew', []) if person['job'] == 'Producer'], # продюссер
                'writer': [person['name'] for person in details.get('credits', {}).get('crew', []) if person['job'] == 'Writer'], # сценарист
                'editor': [person['name'] for person in details.get('credits', {}).get('crew', []) if person['job'] == 'Editor'], # режиссер монтажа
                'cinematographer': [person['name'] for person in details.get('credits', {}).get('crew', []) if person['job'] == 'Director of Photography'], # оператор
                
                # финансовая информация
                'budget': details.get('budget', 0),
                'revenue': details.get('revenue', 0),
                
                # технические детали
                'runtime': details.get('runtime', 0),
                'tagline': details.get('tagline', ''),
                'production_countries': [country['name'] for country in details.get('production_countries', [])], # формируем список из стран продакшена
                'original_language': details.get('original_language', ''),
                'production_companies': [company['name'] for company in details.get('production_companies', [])], # формируем список из названий производящих компаний
                
                # внешние ссылки
                'imdb_id': details.get('external_ids', {}).get('imdb_id', ''),
                
                # жанры
                'genres': [genre['name'] for genre in details.get('genres', [])],
                
                # через питоновские срезы составляю несколько колонок про каст фильма
                'full_cast': [
                    actor['name'] for actor in details.get('credits', {}).get('cast', [])[:]
                ],
                'top_cast': [
                    actor['name'] for actor in details.get('credits', {}).get('cast', [])[:5] # главные герои
                ],
                'secondary_cast': [
                    actor['name'] for actor in details.get('credits', {}).get('cast', [])[5:15] # второстепенные герои
                ],
                'episodic_cast': [
                    actor['name'] for actor in details.get('credits', {}).get('cast', [])[15:] # эпизодические герои
                ]
            }
            
            detailed_movies.append(movie_data)
            
        except Exception as e:
            print(f"не удалось получить данные для фильма {movie['id']}: {e}")
    
    return pd.DataFrame(detailed_movies)

# основной блок выполнения
if __name__ == '__main__':
    # собираем данные
    print("идет сбор данных...")
    sci_fi_movies = get_sci_fi_movies()
    
    # сохраняем результат
    os.makedirs('data/raw', exist_ok=True)
    sci_fi_movies.to_csv('data/raw/sci_fi_movies_tmdb.csv', index=False)
# Out:
# идет сбор данных...
# проблема со страницей 501: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=501
# проблема со страницей 502: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=502
# проблема со страницей 504: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=504
# проблема со страницей 503: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=503
# проблема со страницей 505: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=505
# проблема со страницей 506: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=506
# проблема со страницей 507: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=507
# проблема со страницей 511: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=511
# проблема со страницей 510: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=510
# проблема со страницей 508: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=508
# проблема со страницей 509: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=509
# проблема со страницей 512: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=512
# проблема со страницей 513: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=513
# проблема со страницей 514: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=514
# проблема со страницей 517: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=517
# проблема со страницей 515: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=515
# проблема со страницей 519: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=519
# проблема со страницей 521: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=521
# проблема со страницей 516: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=516
# проблема со страницей 522: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=522
# проблема со страницей 518: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=518
# проблема со страницей 527: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=527
# проблема со страницей 523: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=523
# проблема со страницей 520: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=520
# проблема со страницей 528: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=528
# проблема со страницей 524: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=524
# проблема со страницей 525: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=525
# проблема со страницей 526: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=526
# проблема со страницей 530: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=530
# проблема со страницей 531: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=531
# проблема со страницей 529: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=529
# проблема со страницей 535: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=535
# проблема со страницей 532: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=532
# проблема со страницей 538: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=538
# проблема со страницей 533: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=533
# проблема со страницей 540: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=540
# проблема со страницей 539: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=539
# проблема со страницей 534: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=534
# проблема со страницей 541: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=541
# проблема со страницей 536: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=536
# проблема со страницей 545: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=545
# проблема со страницей 542: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=542
# проблема со страницей 537: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=537
# проблема со страницей 548: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=548
# проблема со страницей 543: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=543
# проблема со страницей 547: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=547
# проблема со страницей 549: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=549
# проблема со страницей 546: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=546
# проблема со страницей 544: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=544
# проблема со страницей 550: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=550
# проблема со страницей 551: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=551
# проблема со страницей 555: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=555
# проблема со страницей 553: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=553
# проблема со страницей 552: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=552
# проблема со страницей 554: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=554
# проблема со страницей 557: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=557
# проблема со страницей 562: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=562
# проблема со страницей 556: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=556
# проблема со страницей 559: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=559
# проблема со страницей 563: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=563
# проблема со страницей 558: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=558
# проблема со страницей 561: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=561
# проблема со страницей 560: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=560
# проблема со страницей 566: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=566
# проблема со страницей 571: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=571
# проблема со страницей 565: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=565
# проблема со страницей 567: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=567
# проблема со страницей 564: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=564
# проблема со страницей 574: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=574
# проблема со страницей 568: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=568
# проблема со страницей 575: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=575
# проблема со страницей 576: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=576
# проблема со страницей 569: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=569
# проблема со страницей 577: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=577
# проблема со страницей 570: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=570
# проблема со страницей 580: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=580
# проблема со страницей 578: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=578
# проблема со страницей 572: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=572
# проблема со страницей 581: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=581
# проблема со страницей 583: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=583
# проблема со страницей 573: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=573
# проблема со страницей 585: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=585
# проблема со страницей 584: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=584
# проблема со страницей 579: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=579
# проблема со страницей 589: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=589
# проблема со страницей 587: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=587
# проблема со страницей 582: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=582
# проблема со страницей 591: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=591
# проблема со страницей 593: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=593
# проблема со страницей 586: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=586
# проблема со страницей 594: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=594
# проблема со страницей 588: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=588
# проблема со страницей 598: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=598
# проблема со страницей 590: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=590
# проблема со страницей 596: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=596
# проблема со страницей 599: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=599
# проблема со страницей 597: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=597
# проблема со страницей 592: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=592
# проблема со страницей 600: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=600
# проблема со страницей 595: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=595
# проблема со страницей 603: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=603
# проблема со страницей 601: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=601
# проблема со страницей 609: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=609
# проблема со страницей 602: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=602
# проблема со страницей 604: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=604
# проблема со страницей 606: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=606
# проблема со страницей 607: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=607
# проблема со страницей 605: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=605
# проблема со страницей 613: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=613
# проблема со страницей 608: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=608
# проблема со страницей 611: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=611
# проблема со страницей 618: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=618
# проблема со страницей 610: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=610
# проблема со страницей 612: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=612
# проблема со страницей 615: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=615
# проблема со страницей 614: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=614
# проблема со страницей 622: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=622
# проблема со страницей 617: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=617
# проблема со страницей 616: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=616
# проблема со страницей 624: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=624
# проблема со страницей 619: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=619
# проблема со страницей 620: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=620
# проблема со страницей 623: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=623
# проблема со страницей 621: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=621
# проблема со страницей 630: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=630
# проблема со страницей 629: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=629
# проблема со страницей 626: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=626
# проблема со страницей 631: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=631
# проблема со страницей 632: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=632
# проблема со страницей 625: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=625
# проблема со страницей 634: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=634
# проблема со страницей 636: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=636
# проблема со страницей 627: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=627
# проблема со страницей 635: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=635
# проблема со страницей 638: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=638
# проблема со страницей 628: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=628
# проблема со страницей 641: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=641
# проблема со страницей 640: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=640
# проблема со страницей 633: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=633
# проблема со страницей 642: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=642
# проблема со страницей 643: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=643
# проблема со страницей 637: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=637
# проблема со страницей 645: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=645
# проблема со страницей 644: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=644
# проблема со страницей 639: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=639
# проблема со страницей 646: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=646
# проблема со страницей 648: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=648
# проблема со страницей 647: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=647
# проблема со страницей 651: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=651
# проблема со страницей 649: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=649
# проблема со страницей 650: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=650
# проблема со страницей 655: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=655
# проблема со страницей 652: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=652
# проблема со страницей 653: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=653
# проблема со страницей 659: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=659
# проблема со страницей 660: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=660
# проблема со страницей 654: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=654
# проблема со страницей 663: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=663
# проблема со страницей 656: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=656
# проблема со страницей 666: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=666
# проблема со страницей 667: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=667
# проблема со страницей 657: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=657
# проблема со страницей 670: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=670
# проблема со страницей 668: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=668
# проблема со страницей 658: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=658
# проблема со страницей 672: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=672
# проблема со страницей 669: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=669
# проблема со страницей 661: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=661
# проблема со страницей 673: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=673
# проблема со страницей 662: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=662
# проблема со страницей 671: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=671
# проблема со страницей 674: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=674
# проблема со страницей 664: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=664
# проблема со страницей 676: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=676
# проблема со страницей 675: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=675
# проблема со страницей 677: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=677проблема со страницей 665: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=665
#
# проблема со страницей 680: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=680
# проблема со страницей 678: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=678
# проблема со страницей 679: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=679
# проблема со страницей 681: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=681
# проблема со страницей 682: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=682
# проблема со страницей 684: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=684
# проблема со страницей 683: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=683
# проблема со страницей 687: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=687
# проблема со страницей 686: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=686
# проблема со страницей 685: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=685
# проблема со страницей 688: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=688
# проблема со страницей 689: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=689
# проблема со страницей 693: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=693
# проблема со страницей 691: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=691
# проблема со страницей 696: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=696
# проблема со страницей 690: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=690
# проблема со страницей 695: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=695
# проблема со страницей 698: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=698
# проблема со страницей 692: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=692
# проблема со страницей 701: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=701
# проблема со страницей 700: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=700
# проблема со страницей 694: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=694
# проблема со страницей 702: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=702
# проблема со страницей 704: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=704
# проблема со страницей 697: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=697
# проблема со страницей 703: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=703
# проблема со страницей 699: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=699
# проблема со страницей 705: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=705
# проблема со страницей 710: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=710
# проблема со страницей 707: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=707
# проблема со страницей 706: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=706
# проблема со страницей 712: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=712
# проблема со страницей 709: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=709
# проблема со страницей 708: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=708
# проблема со страницей 716: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=716
# проблема со страницей 711: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=711
# проблема со страницей 713: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=713
# проблема со страницей 717: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=717
# проблема со страницей 714: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=714
# проблема со страницей 715: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=715
# проблема со страницей 719: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=719
# проблема со страницей 721: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=721
# проблема со страницей 718: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=718
# проблема со страницей 722: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=722
# проблема со страницей 725: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=725
# проблема со страницей 720: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=720
# проблема со страницей 724: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=724
# проблема со страницей 726: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=726
# проблема со страницей 723: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=723
# проблема со страницей 727: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=727
# проблема со страницей 728: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=728
# проблема со страницей 729: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=729
# проблема со страницей 733: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=733
# проблема со страницей 730: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=730
# проблема со страницей 731: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=731
# проблема со страницей 735: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=735
# проблема со страницей 734: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=734
# проблема со страницей 732: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=732
# проблема со страницей 736: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=736
# проблема со страницей 738: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=738
# проблема со страницей 737: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=737
# проблема со страницей 739: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=739
# проблема со страницей 741: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=741
# проблема со страницей 740: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=740
# проблема со страницей 743: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=743
# проблема со страницей 742: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=742
# проблема со страницей 746: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=746
# проблема со страницей 745: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=745
# проблема со страницей 744: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=744
# проблема со страницей 748: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=748
# проблема со страницей 747: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=747
# проблема со страницей 750: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=750
# проблема со страницей 749: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/discover/movie?api_key=bcd3dc372c98663f3b351a83592efe6a&with_genres=878&page=749

# %%
# выводим статистику и осматриваем датасет на целостность
print(f"собрано фильмов: {len(sci_fi_movies)}")
df = pd.read_csv('data/raw/sci_fi_movies_tmdb.csv')

display(df.sort_values('release_date', ascending=True))
# Out:
# собрано фильмов: 10000
#            id                                    title  \
# 9796   189571                   The Mechanical Butcher
# 7514   119974              Turn-of-the-Century Surgery
# 8288   183601                   An Over-Incubated Baby
# 1289      775                       A Trip to the Moon
# 5512     2963                    The Impossible Voyage
# ...       ...                                      ...
# 9964   229718                                     XJ-1
# 9974  1384339  Untitled Simon Kinberg Star Wars Film 2
# 9975  1381202                 The Embers and the Stars
# 9978  1318314                            Irandu Vaanam
# 9999   536196                                   STATUS
#
#                                original_title  \
# 9796                 La Charcuterie mécanique
# 7514                  Chirurgie fin de siècle
# 8288                   An Over-Incubated Baby
# 1289                   Le Voyage dans la Lune
# 5512         Le Voyage à travers l'impossible
# ...                                       ...
# 9964                                     XJ-1
# 9974  Untitled Simon Kinberg Star Wars Film 2
# 9975                 The Embers and the Stars
# 9978                             இரண்டு வானம்
# 9999                                   STATUS
#
#                                                overview release_date  \
# 9796  A butcher puts a full-grown live pig into his ...   1896-04-18
# 7514  George Mélies made a version of this a few yea...   1900-01-01
# 8288  An up to date idea and a great picture. The pr...   1901-08-01
# 1289  Professor Barbenfouillis and five of his colle...   1902-06-15
# 5512  Using every known means of transportation, sev...   1904-11-10
# ...                                                 ...          ...
# 9964  A young man meets a mysterious cyberspace pers...          NaN
# 9974  The second film in a new trilogy of Star Wars ...          NaN
# 9975  An astrophysicist, after making an extraterres...          NaN
# 9978  Upcoming Romantic Fantasy Film Starring Vishnu...          NaN
# 9999  Statlink is the ultimate modern connection. Pl...          NaN
#
#       popularity  imdb_average  imdb_count     imdb_id  \
# 9796    0.398500           5.7          45   tt0212052
# 7514    0.068990           4.9          21   tt0000286
# 8288    0.077464           4.9          11   tt0212411
# 1289    1.042573           7.9        1821   tt0000417
# 5512    1.014500           7.2         190   tt0000499
# ...          ...           ...         ...         ...
# 9964    0.059824           0.0           0         NaN
# 9974    0.053607           0.0           0         NaN
# 9975    0.053607           0.0           0  tt33372918
# 9978    0.053607           0.0           0         NaN
# 9999    0.382500           0.0           0   tt1887857
#
#                     director  ... runtime  \
# 9796       ['Louis Lumière']  ...       1
# 7514    ['Alice Guy-Blaché']  ...       2
# 8288     ['Walter R. Booth']  ...       1
# 1289      ['Georges Méliès']  ...      15
# 5512      ['Georges Méliès']  ...      20
# ...                      ...  ...     ...
# 9964    ['Marius Swanepoel']  ...      97
# 9974                      []  ...       0
# 9975       ['William Woods']  ...       0
# 9978           ['Ram Kumar']  ...       0
# 9999  ['Richard Williamson']  ...      20
#
#                                              tagline  \
# 9796                                             NaN
# 7514                                             NaN
# 8288                                             NaN
# 1289                                             NaN
# 5512                                             NaN
# ...                                              ...
# 9964                                             NaN
# 9974                                             NaN
# 9975                                             NaN
# 9978                                             NaN
# 9999  Welcome to the evolution of social networking.
#
#               production_countries original_language  \
# 9796                    ['France']                fr
# 7514                    ['France']                fr
# 8288            ['United Kingdom']                en
# 1289                    ['France']                fr
# 5512                    ['France']                fr
# ...                            ...               ...
# 9964              ['South Africa']                en
# 9974  ['United States of America']                en
# 9975                    ['Canada']                en
# 9978                     ['India']                ta
# 9999                            []                en
#
#                                    production_companies  \
# 9796                                        ['Lumière']
# 7514                                        ['Gaumont']
# 8288                                 ['Robert W. Paul']
# 1289                                      ['Star Film']
# 5512                    ['Georges Méliès', 'Star Film']
# ...                                                 ...
# 9964                                  ['Eternal Films']
# 9974                                 ['Lucasfilm Ltd.']
# 9975  ['Sara Fost Pictures', 'Obvious Allegory', 'Ti...
# 9978                            ['Sathya Jyothi Films']
# 9999                                                 []
#
#                                                  genres  \
# 9796                      ['Comedy', 'Science Fiction']
# 7514            ['Science Fiction', 'Horror', 'Comedy']
# 8288                      ['Science Fiction', 'Comedy']
# 1289                   ['Adventure', 'Science Fiction']
# 5512  ['Adventure', 'Comedy', 'Fantasy', 'Science Fi...
# ...                                                 ...
# 9964                                ['Science Fiction']
# 9974                                ['Science Fiction']
# 9975                    ['Science Fiction', 'Thriller']
# 9978          ['Romance', 'Fantasy', 'Science Fiction']
# 9999                     ['Romance', 'Science Fiction']
#
#                                               full_cast  \
# 9796                                                 []
# 7514                                                 []
# 8288                                                 []
# 1289  ['Georges Méliès', 'Bleuette Bernon', 'Françoi...
# 5512  ['Georges Méliès', 'Fernande Albeny', "Jehanne...
# ...                                                 ...
# 9964                                                 []
# 9974                                                 []
# 9975  ['Constance Wu', "Mark O'Brien", 'William Fich...
# 9978                 ['Vishnu Vishal', 'Mamitha Baiju']
# 9999                                                 []
#
#                                                top_cast  \
# 9796                                                 []
# 7514                                                 []
# 8288                                                 []
# 1289  ['Georges Méliès', 'Bleuette Bernon', 'Françoi...
# 5512  ['Georges Méliès', 'Fernande Albeny', "Jehanne...
# ...                                                 ...
# 9964                                                 []
# 9974                                                 []
# 9975  ['Constance Wu', "Mark O'Brien", 'William Fich...
# 9978                 ['Vishnu Vishal', 'Mamitha Baiju']
# 9999                                                 []
#
#                                          secondary_cast episodic_cast
# 9796                                                 []            []
# 7514                                                 []            []
# 8288                                                 []            []
# 1289  ['Brunnet', 'Depierre', 'Farjaut', 'Kelm', "Je...            []
# 5512                                                 []            []
# ...                                                 ...           ...
# 9964                                                 []            []
# 9974                                                 []            []
# 9975                                                 []            []
# 9978                                                 []            []
# 9999                                                 []            []
#
# [10000 rows x 26 columns]

# %% [markdown]
# ## Этап 2: Обогащение данных
#
# Насмотря на то, что датасет получился разнообразным, в ходе исследования важно подробно изучить не только технические моменты производства фильмов, но и общественные аспекты восприятие научной фантастики.
#
# Для полной репрезентативности я хочу расширить датасет засчет другого API,  чтобы получить информацию о фестивальных наградах и рейтинге на дргуих рейтингов -  Rotten Tomatoes, Metacritic и Metascore.

# %% [markdown]
# ### Обогащение датасета колонками из дополнительного API (OMDB)

# %% [markdown]
# Для того чтобы проверить, как выглядит разметка данных базы OMDB, мы можем взять случайный фильм из нашего текущего датасета и запросить его полную информацию через API OMDB. Так мы узнаем, какими дополнительными колонками мы сожем обогатить датасет.

# %%
OMDB_API_KEY = 'f1f15728'
imdb_id = 'tt0083658'  # 

url = f"http://www.omdbapi.com/?i={imdb_id}&apikey={OMDB_API_KEY}&tomatoes=true&plot=short"
response = requests.get(url)
print(response.json())
# Out:
# {'Title': 'Blade Runner', 'Year': '1982', 'Rated': 'R', 'Released': '25 Jun 1982', 'Runtime': '117 min', 'Genre': 'Action, Drama, Sci-Fi', 'Director': 'Ridley Scott', 'Writer': 'Hampton Fancher, David Webb Peoples, Philip K. Dick', 'Actors': 'Harrison Ford, Rutger Hauer, Sean Young', 'Plot': 'A blade runner must pursue and terminate four replicants who stole a ship in space and have returned to Earth to find their creator.', 'Language': 'English, German, Cantonese, Japanese, Hungarian, Arabic, Korean', 'Country': 'United States, United Kingdom', 'Awards': 'Nominated for 2 Oscars. 13 wins & 22 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BOWQ4YTBmNTQtMDYxMC00NGFjLTkwOGQtNzdhNmY1Nzc1MzUxXkEyXkFqcGc@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}, {'Source': 'Rotten Tomatoes', 'Value': '89%'}, {'Source': 'Metacritic', 'Value': '84/100'}], 'Metascore': '84', 'imdbRating': '8.1', 'imdbVotes': '842,743', 'imdbID': 'tt0083658', 'Type': 'movie', 'tomatoMeter': 'N/A', 'tomatoImage': 'N/A', 'tomatoRating': 'N/A', 'tomatoReviews': 'N/A', 'tomatoFresh': 'N/A', 'tomatoRotten': 'N/A', 'tomatoConsensus': 'N/A', 'tomatoUserMeter': 'N/A', 'tomatoUserRating': 'N/A', 'tomatoUserReviews': 'N/A', 'tomatoURL': 'https://www.rottentomatoes.com/m/blade_runner/', 'DVD': 'N/A', 'BoxOffice': '$32,914,489', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}

# %% [markdown]
# #### Особенннсти сбора данных
# 1. **Параллельная загрузка**
#    - 5 одновременных потоков
#    - Обработка данных для каждого фильма по IMDb ID
#
# 2. **Детализация информации**
#
#    Для каждого фильма извлекаем данные о наградах и рейтингах с платформ:
#    > `Awards` (Награды), `Rotten_Tomatoes` (Рейтинг на Rotten Tomatoes), `Metacritic` (Рейтинг на Metacritic), `Metascore` (Общий рейтинг)
#
# 3. **Контроль качества**
#    Проверка успешности запроса и обработка ошибок:
#    ```python
#    response.raise_for_status()  # проверка HTTP-ошибок
#    if not movie_details:  # пропуск фильмов без данных
#    ```
#
# **Защитные механизмы**
# - Пауза от `0.5 до 2 секунд` между запросами для предотвращения перегрузки сервера и снижения нагрузки на API
# - Повторная попытка при сбоях
# - Логирование ошибок для отслеживания проблемных запросов
#
# **Особенности:**
# - Автоматическое добавление данных о наградах и рейтингах в основной датафрейм
# - Сохранение дополнительных данных в том же CSV
# - Обработка данных в реальном времени, с логированием хода работы
#
# > **Производительность**: На тестах сбор дополнительных данных для 10,000 фильмов занимает ~10-15 минут при стабильном интернет-соединении.
#
# ---
#
# #### Пояснение к коду:
#
# - **`extract_movie_data(movie_details)`** — функция извлекает нужные данные о фильме, такие как награды и рейтинги с различных платформ.
#
# - **`response.status_code == 200`** — проверка на успешный HTTP-статус:
#     - В случае ошибки возвращает `None`
#     - При успешном запросе преобразует ответ в Python-словарь с помощью `response.json()`
#
# - **Как реализуется <font color="#f79646">параллельная обработка</font>**:
#     - Используется многозадачность с `ThreadPoolExecutor` для обработки фильмов.
#     - Ограничение до 5 одновременных потоков.
#         ```python
#         with ThreadPoolExecutor(max_workers=5) as executor:
#             futures = {executor.submit(process_movie, imdb_id): imdb_id for imdb_id in imdb_ids}
#         ```
#     - Применяется случайная задержка между запросами для снижения нагрузки на API (использование time и random)

# %% [markdown]
# > **Производительность**: частота выдачи запросов OMDB  десятикратно медленнее, чем TMDB - на объединение 10,000 строк с имеющейся базой <font color="#ff0000">потребовалось почти 3 часа</font> (176 минут) 😭.

# %%
import random

def extract_movie_data(movie_details):
    if not movie_details or movie_details.get('Response') == 'False': #если сли данных о фильме нет или запрос не удался, возвращаем дефолтные значения
        return {
            'Awards': 'No data',
            'Rotten_Tomatoes': 'N/A',
            'Metacritic': 'N/A',
            'Metascore': 'N/A'
        }
    
    # ищем рейтинг rotten tomatoes в рамках поля 'Ratings', о котором мы узнали, когда изучали разметку
    rt_rating = next((rating['Value'] for rating in movie_details.get('Ratings', []) 
                      if rating['Source'] == 'Rotten Tomatoes'), 'N/A')
    
    return {
        'Awards': movie_details.get('Awards', 'No awards data'),
        'Rotten_Tomatoes': rt_rating,
        'Metacritic': rt_rating.rstrip('%') if rt_rating != 'N/A' else 'N/A',
        'Metascore': 'N/A'
    }

def safe_api_request(imdb_id): ## устанавливаем, как будет работать наш запрос с сервером omdb
    url = f"http://www.omdbapi.com/?i={imdb_id}&apikey={OMDB_API_KEY}&tomatoes=true&plot=short"
    try:
        response = requests.get(url, timeout=15) # ограничение 15 секунд на запрос
        return response.json() if response.status_code == 200 else None
    except Exception:
        return None

def process_movie(imdb_id):
    time.sleep(random.uniform(0.5, 2))
    
    movie_details = safe_api_request(imdb_id)
    movie_data = extract_movie_data(movie_details)
    movie_data['imdb_id'] = imdb_id
    
    return movie_data

# функция для объединения данных иOMDB с основным датасетом
def merge_omdb_data(df): 
    imdb_ids = df['imdb_id'].tolist() # по свойству 'imdb_id' извлекаем строки из основного датасета
    
    processed_data = [] # список записи для выполненных и обрботанных записей
    
    # создаем пул потоков для параллельной обработки
    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = {executor.submit(process_movie, imdb_id): imdb_id for imdb_id in imdb_ids} # для каждого imdb_id создаем задачу на выполнение
        
        for i, future in enumerate(as_completed(futures), 1):
            result = future.result()
            processed_data.append(result)
            
             # система оповещения и контроля: раз в 50 итераций (обработанных фильмов) счетчик будет активироваться и выводить сообщение
            if i % 50 == 0:
                print(f"добавлено {i} фильмов...")
    
    omdb_df = pd.DataFrame(processed_data) # преобразуем обработанные данные в датафрейм
    df_merged = df.merge(omdb_df, on='imdb_id', how='left') # объединяем исходный датасет с новым датасетом из OMDB, ставя коновые колоки слева
    
    return df_merged

# загружаем сущсетвуюзщйи файл с датасетов
df = pd.read_csv('data/raw/sci_fi_movies_tmdb.csv')

# обхединяем  
df_merged = merge_omdb_data(df)

# сохраняем
df_merged.to_csv('data/raw/sci_fi_movies_merged.csv', index=False)
# Out:
# добавлено 50 фильмов...
# добавлено 100 фильмов...
# добавлено 150 фильмов...
# добавлено 200 фильмов...
# добавлено 250 фильмов...
# добавлено 300 фильмов...
# добавлено 350 фильмов...
# добавлено 400 фильмов...
# добавлено 450 фильмов...
# добавлено 500 фильмов...
# добавлено 550 фильмов...
# добавлено 600 фильмов...
# добавлено 650 фильмов...
# добавлено 700 фильмов...
# добавлено 750 фильмов...
# добавлено 800 фильмов...
# добавлено 850 фильмов...
# добавлено 900 фильмов...
# добавлено 950 фильмов...
# добавлено 1000 фильмов...
# добавлено 1050 фильмов...
# добавлено 1100 фильмов...
# добавлено 1150 фильмов...
# добавлено 1200 фильмов...
# добавлено 1250 фильмов...
# добавлено 1300 фильмов...
# добавлено 1350 фильмов...
# добавлено 1400 фильмов...
# добавлено 1450 фильмов...
# добавлено 1500 фильмов...
# добавлено 1550 фильмов...
# добавлено 1600 фильмов...
# добавлено 1650 фильмов...
# добавлено 1700 фильмов...
# добавлено 1750 фильмов...
# добавлено 1800 фильмов...
# добавлено 1850 фильмов...
# добавлено 1900 фильмов...
# добавлено 1950 фильмов...
# добавлено 2000 фильмов...
# добавлено 2050 фильмов...
# добавлено 2100 фильмов...
# добавлено 2150 фильмов...
# добавлено 2200 фильмов...
# добавлено 2250 фильмов...
# добавлено 2300 фильмов...
# добавлено 2350 фильмов...
# добавлено 2400 фильмов...
# добавлено 2450 фильмов...
# добавлено 2500 фильмов...
# добавлено 2550 фильмов...
# добавлено 2600 фильмов...
# добавлено 2650 фильмов...
# добавлено 2700 фильмов...
# добавлено 2750 фильмов...
# добавлено 2800 фильмов...
# добавлено 2850 фильмов...
# добавлено 2900 фильмов...
# добавлено 2950 фильмов...
# добавлено 3000 фильмов...
# добавлено 3050 фильмов...
# добавлено 3100 фильмов...
# добавлено 3150 фильмов...
# добавлено 3200 фильмов...
# добавлено 3250 фильмов...
# добавлено 3300 фильмов...
# добавлено 3350 фильмов...
# добавлено 3400 фильмов...
# добавлено 3450 фильмов...
# добавлено 3500 фильмов...
# добавлено 3550 фильмов...
# добавлено 3600 фильмов...
# добавлено 3650 фильмов...
# добавлено 3700 фильмов...
# добавлено 3750 фильмов...
# добавлено 3800 фильмов...
# добавлено 3850 фильмов...
# добавлено 3900 фильмов...
# добавлено 3950 фильмов...
# добавлено 4000 фильмов...
# добавлено 4050 фильмов...
# добавлено 4100 фильмов...
# добавлено 4150 фильмов...
# добавлено 4200 фильмов...
# добавлено 4250 фильмов...
# добавлено 4300 фильмов...
# добавлено 4350 фильмов...
# добавлено 4400 фильмов...
# добавлено 4450 фильмов...
# добавлено 4500 фильмов...
# добавлено 4550 фильмов...
# добавлено 4600 фильмов...
# добавлено 4650 фильмов...
# добавлено 4700 фильмов...
# добавлено 4750 фильмов...
# добавлено 4800 фильмов...
# добавлено 4850 фильмов...
# добавлено 4900 фильмов...
# добавлено 4950 фильмов...
# добавлено 5000 фильмов...
# добавлено 5050 фильмов...
# добавлено 5100 фильмов...
# добавлено 5150 фильмов...
# добавлено 5200 фильмов...
# добавлено 5250 фильмов...
# добавлено 5300 фильмов...
# добавлено 5350 фильмов...
# добавлено 5400 фильмов...
# добавлено 5450 фильмов...
# добавлено 5500 фильмов...
# добавлено 5550 фильмов...
# добавлено 5600 фильмов...
# добавлено 5650 фильмов...
# добавлено 5700 фильмов...
# добавлено 5750 фильмов...
# добавлено 5800 фильмов...
# добавлено 5850 фильмов...
# добавлено 5900 фильмов...
# добавлено 5950 фильмов...
# добавлено 6000 фильмов...
# добавлено 6050 фильмов...
# добавлено 6100 фильмов...
# добавлено 6150 фильмов...
# добавлено 6200 фильмов...
# добавлено 6250 фильмов...
# добавлено 6300 фильмов...
# добавлено 6350 фильмов...
# добавлено 6400 фильмов...
# добавлено 6450 фильмов...
# добавлено 6500 фильмов...
# добавлено 6550 фильмов...
# добавлено 6600 фильмов...
# добавлено 6650 фильмов...
# добавлено 6700 фильмов...
# добавлено 6750 фильмов...
# добавлено 6800 фильмов...
# добавлено 6850 фильмов...
# добавлено 6900 фильмов...
# добавлено 6950 фильмов...
# добавлено 7000 фильмов...
# добавлено 7050 фильмов...
# добавлено 7100 фильмов...
# добавлено 7150 фильмов...
# добавлено 7200 фильмов...
# добавлено 7250 фильмов...
# добавлено 7300 фильмов...
# добавлено 7350 фильмов...
# добавлено 7400 фильмов...
# добавлено 7450 фильмов...
# добавлено 7500 фильмов...
# добавлено 7550 фильмов...
# добавлено 7600 фильмов...
# добавлено 7650 фильмов...
# добавлено 7700 фильмов...
# добавлено 7750 фильмов...
# добавлено 7800 фильмов...
# добавлено 7850 фильмов...
# добавлено 7900 фильмов...
# добавлено 7950 фильмов...
# добавлено 8000 фильмов...
# добавлено 8050 фильмов...
# добавлено 8100 фильмов...
# добавлено 8150 фильмов...
# добавлено 8200 фильмов...
# добавлено 8250 фильмов...
# добавлено 8300 фильмов...
# добавлено 8350 фильмов...
# добавлено 8400 фильмов...
# добавлено 8450 фильмов...
# добавлено 8500 фильмов...
# добавлено 8550 фильмов...
# добавлено 8600 фильмов...
# добавлено 8650 фильмов...
# добавлено 8700 фильмов...
# добавлено 8750 фильмов...
# добавлено 8800 фильмов...
# добавлено 8850 фильмов...
# добавлено 8900 фильмов...
# добавлено 8950 фильмов...
# добавлено 9000 фильмов...
# добавлено 9050 фильмов...
# добавлено 9100 фильмов...
# добавлено 9150 фильмов...
# добавлено 9200 фильмов...
# добавлено 9250 фильмов...
# добавлено 9300 фильмов...
# добавлено 9350 фильмов...
# добавлено 9400 фильмов...
# добавлено 9450 фильмов...
# добавлено 9500 фильмов...
# добавлено 9550 фильмов...
# добавлено 9600 фильмов...
# добавлено 9650 фильмов...
# добавлено 9700 фильмов...
# добавлено 9750 фильмов...
# добавлено 9800 фильмов...
# добавлено 9850 фильмов...
# добавлено 9900 фильмов...
# добавлено 9950 фильмов...
# добавлено 10000 фильмов...

# %%
df = df.drop_duplicates()  # удалим строчки-дубликаты, прежде чем сохранять датафрейм
df = pd.read_csv('data/raw/sci_fi_movies_merged.csv')

df.head()
# Out:
#        id               title      original_title  \
# 0    2756           The Abyss           The Abyss
# 1     185  A Clockwork Orange  A Clockwork Orange
# 2  720321             Breathe             Breathe
# 3     871  Planet of the Apes  Planet of the Apes
# 4  760873          The Colony               Tides
#
#                                             overview release_date  popularity  \
# 0  A civilian oil rig crew is recruited to conduc...   1989-08-09    3.665648
# 1  In a near-future Britain, young Alexander DeLa...   1971-12-19    4.283898
# 2  Air-supply is scarce in the near future, forci...   2024-04-04    3.567976
# 3  Astronaut Taylor crash lands on a distant plan...   1968-02-07    4.094930
# 4  In the not-too-distant future: after a global ...   2021-08-26    3.646416
#
#    imdb_average  imdb_count     imdb_id                   director  ...  \
# 0         7.400        3082   tt0096754          ['James Cameron']  ...
# 1         8.200       13078   tt0066921        ['Stanley Kubrick']  ...
# 2         5.806         196  tt11540468         ['Stefon Bristol']  ...
# 3         7.600        3630   tt0063442  ['Franklin J. Schaffner']  ...
# 4         5.700         290   tt6506264           ['Tim Fehlbaum']  ...
#
#                                 production_companies  \
# 0            ['20th Century Fox', 'Pacific Western']
# 1  ['Warner Bros. Pictures', 'Hawk Films', 'Stanl...
# 2  ['Thunder Road', 'Capstone Studios', 'Streamli...
# 3          ['APJAC Productions', '20th Century Fox']
# 4  ['BerghausWöbke Filmproduktion', 'Vega Film', ...
#
#                                               genres  \
# 0  ['Adventure', 'Action', 'Thriller', 'Science F...
# 1                       ['Science Fiction', 'Crime']
# 2  ['Action', 'Science Fiction', 'Mystery', 'Thri...
# 3  ['Science Fiction', 'Adventure', 'Drama', 'Act...
# 4                    ['Science Fiction', 'Thriller']
#
#                                            full_cast  \
# 0  ['Ed Harris', 'Mary Elizabeth Mastrantonio', '...
# 1  ['Malcolm McDowell', 'Patrick Magee', 'Carl Du...
# 2  ['Jennifer Hudson', 'Milla Jovovich', 'Quvenzh...
# 3  ['Charlton Heston', 'Roddy McDowall', 'Kim Hun...
# 4  ['Nora Arnezeder', 'Iain Glen', 'Sarah-Sofie B...
#
#                                             top_cast  \
# 0  ['Ed Harris', 'Mary Elizabeth Mastrantonio', '...
# 1  ['Malcolm McDowell', 'Patrick Magee', 'Carl Du...
# 2  ['Jennifer Hudson', 'Milla Jovovich', 'Quvenzh...
# 3  ['Charlton Heston', 'Roddy McDowall', 'Kim Hun...
# 4  ['Nora Arnezeder', 'Iain Glen', 'Sarah-Sofie B...
#
#                                       secondary_cast  \
# 0  ['John Bedford Lloyd', 'Kimberly Scott', 'Chri...
# 1  ['James Marcus', 'Michael Tarn', 'Miriam Karli...
# 2  ['Raúl Castillo', 'James Saito', 'Dan Martin',...
# 3  ['James Daly', 'Linda Harrison', 'Robert Gunne...
# 4  ['Joel Basman', 'Kotti Yun', 'Bella Bading', '...
#
#                                        episodic_cast  \
# 0  ['J. Kenneth Campbell', 'Peter Ratray', 'Micha...
# 1  ['Michael Gover', 'Godfrey Quigley', 'Madge Ry...
# 2                                                 []
# 3  ['Martin Abrahams', 'Army Archerd', 'James Bac...
# 4                                                 []
#
#                                               Awards Rotten_Tomatoes  \
# 0         Won 1 Oscar. 9 wins & 16 nominations total             89%
# 1  Nominated for 4 Oscars. 12 wins & 26 nominatio...             86%
# 2                                                NaN             14%
# 3  Nominated for 2 Oscars. 6 wins & 5 nominations...             86%
# 4                            10 wins & 4 nominations             54%
#
#   Metacritic Metascore
# 0       89.0       NaN
# 1       86.0       NaN
# 2       14.0       NaN
# 3       86.0       NaN
# 4       54.0       NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Обогащение данных через выявление дополнительных колонок
#
#  В рамках текущего этапа важно сформировать несколько дополнительных колонок, которые позволят более детально оценить финансовую эффективность, творческую составляющую и временные тренды фильмов.

# %% [markdown]
# 1) `ROI (Return on Investment)`
#
#     ✅ Показывает отношение прибыли к бюджету, что является важным индикатором <u>финансовой эффективности</u> и <u>рентабельности фильма</u>. ROI позволяет лучше понять, насколько прибыльным был фильм в сравнении с его затратами.
#
#     🤔 Рассчитывается как (сборы - бюджет) / бюджет.

# %%
df_merged['roi'] = (df_merged['revenue'] - df_merged['budget']) / df_merged['budget']

# %% [markdown]
# 2) `Profit`
#
#     ✅ Эта колонка помогает понять, сколько прибыли фильм принес в сравнении с его бюджетом, показывая реальный финансовый успех.
#
#     🤔 Формула: сборы - бюджет

# %%
df_merged['profit'] = df_merged['revenue'] - df_merged['budget']

# %% [markdown]
# **3) раскладываем str `Awards` на маленькие колонки**
#
# Изучив датасет, я заметила, что в строковой колонке **Awards** есть множество недостатков, которые затрудняют дальнейшую работу с данными. Во-первых, в колонке смешаны и номинации, и награды, что усложняет их отдельное использование. Во-вторых, многие строки не содержат информации о самих наградах, а лишь упоминают их количество, например "5 nominations" или "3 wins".
#
# Эта колонка имеет большой потенциал для анализа, ведь она дает нам ключевую информацию о признании фильмов. Однако как с ней работать? Конечно, можно попробовать использовать методы фильтрации, такие как `str.contains()`, для поиска и выделения наград, но этого недостаточно для более глубокого анализа.
#
# Мы не можем просто извлечь значение "Oscar" или "Golden Globe" и считать их результатом без более точной обработки.
#
# Поэтому я решила подходить к задаче с трех сторон:
# 1. **Полученные награды** — точно определенные награды, которые фильм получил.
# 2. **Номинации** — количество номинаций, которые фильм получил.
# 3. **Отсутствие награды** — случаи, когда фильм не получил награды, но все же упоминается в колонке "Awards".
#
# Далее, мне нужно решить, как лучше работать с этой информацией: вводить *бинарные колонки* (например, есть номинация или нет), *числовые колонки* (количество выигранных наград или номинаций), или, возможно, *категориальные данные* (тип награды).
#
# В качестве первого шага, я решила воспользоваться более надежной стратегией и создать **номинальные колонки** из наград, которые фильм точно получил. Для этого я  сформулировала **гарантированные лингвистические конструкции**. Например, фразы вроде "Won 1 Oscar" или "Won 4 Golden Globes" однозначно указывают на то, что фильм получил эту награду. Такие строки можно выделить и поместить в отдельные категории.
#
# Затем, на основе этих данных, я решила **типировать** награды, разбив их на всевозможные комбинации типов наград, которые упоминаются в базе. Например, если в одной строке указано "Won 1 Oscar" и "Nominated for 2 Golden Globes", это будет означать, что фильм выиграл один "Oscar" и был номинирован дважды на "Golden Globe".
#
# Таким образом, следующий этап работы с этой колонкой заключается в:
# 1. Выделении всех **конкретных наград**, которые были получены (например, Oscar, Golden Globe).
# 2. Разделении информации на **независимые колонки** с указанием количества выигранных наград и номинаций.
# 3. Формировании **бинарных переменных** для определения наличия тех или иных наград (например, есть ли у фильма "Oscar" или "Golden Globe").

# %% [markdown]
# Итого получаем следующие новые колонки:
#
# - `wins` — извлекаем количество выигранных наград с помощью регулярных выражений, ищем фразу "Won X" в строках и считаем количество таких случаев.
#
# - `nominations` — аналогично извлекаем количество номинаций, ищем "Nominated for X".
#
# - `awards_type` — определяем, какой тип награды присутствует в строке (Oscar, Golden Globe, BAFTA, Cannes), или присваиваем "Other", если тип не найден.

# %%
import re

# Функция для извлечения данных о наградах
def extract_awards_data(awards_string):
    if pd.isna(awards_string) or awards_string == 'No data':
        return {'wins': 0, 'nominations': 0, 'awards_type': 'No data'}
    
    # Ищем количество выигранных наград (например "Won 1", "Won 4")
    wins = sum([int(match) for match in re.findall(r'Won (\d+)', awards_string)])
    
    # Ищем количество номинаций (например "Nominated for 4", "Nominated for 2")
    nominations = sum([int(match) for match in re.findall(r'Nominated for (\d+)', awards_string)])
    
    # Определяем тип награды (Oscar, Golden Globe, BAFTA, Cannes)
    awards_type = 'Other'
    
    # Ищем наличие Oscar, Golden Globe, BAFTA, Cannes в строке
    if 'Oscar' in awards_string:
        awards_type = 'Oscar'
    elif 'Golden Globe' in awards_string:
        awards_type = 'Golden Globe'
    elif 'BAFTA' in awards_string:
        awards_type = 'BAFTA'
    elif 'Cannes' in awards_string:
        awards_type = 'Cannes'

    return {'wins': wins, 'nominations': nominations, 'awards_type': awards_type}

# Применяем функцию ко всем значениям в колонке Awards
df_merged[['wins', 'nominations', 'awards_type']] = df_merged['Awards'].apply(lambda x: pd.Series(extract_awards_data(x)))

# Проверяем результат
df_merged[['title', 'Awards', 'wins', 'nominations', 'awards_type']].head()
df_merged.to_csv('data/raw/sci_fi_movies_merged.csv')

# %% [markdown]
# 💡 Инсайт: для последующего улучшения базы можно вводить бинарные колонки для каждой из кинонаград (has_oscar, has_golden_globe, has_bafta, has_cannes).

# %% [markdown]
# # **Этап 3:** Предобработка и очистка данных
#
# Цель этого этапа — подготовить собранный датасет к анализу: убрать лишние шумы, привести форматы к единому виду и заложить основу для визуализаций, агрегирования и построения моделей.
#
# ---

# %%
df_merged.info()  #проводим осмотр таблицы
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485858 entries, 0 to 485857
# Data columns (total 33 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    485858 non-null  int64
#  1   title                 485858 non-null  object
#  2   original_title        485858 non-null  object
#  3   overview              422264 non-null  object
#  4   release_date          426331 non-null  object
#  5   popularity            485858 non-null  float64
#  6   imdb_average          485858 non-null  float64
#  7   imdb_count            485858 non-null  int64
#  8   imdb_id               9758 non-null    object
#  9   director              485858 non-null  object
#  10  producer              485858 non-null  object
#  11  writer                485858 non-null  object
#  12  editor                485858 non-null  object
#  13  cinematographer       485858 non-null  object
#  14  budget                485858 non-null  int64
#  15  revenue               485858 non-null  int64
#  16  runtime               485858 non-null  int64
#  17  tagline               126007 non-null  object
#  18  production_countries  485858 non-null  object
#  19  original_language     485858 non-null  object
#  20  production_companies  485858 non-null  object
#  21  genres                485858 non-null  object
#  22  full_cast             485858 non-null  object
#  23  top_cast              485858 non-null  object
#  24  secondary_cast        485858 non-null  object
#  25  episodic_cast         485858 non-null  object
#  26  Awards                481254 non-null  object
#  27  Rotten_Tomatoes       2250 non-null    object
#  28  Metacritic            2250 non-null    float64
#  29  Metascore             0 non-null       float64
#  30  wins                  485858 non-null  int64
#  31  nominations           485858 non-null  int64
#  32  awards_type           485858 non-null  object
# dtypes: float64(4), int64(7), object(22)
# memory usage: 122.3+ MB

# %% [markdown]
# ### **1. Работа с пропущенными значениями**
# - Столбцы `release_date`, `overview`, `tagline`, `roi`, `imdb_id` содержат пропуски.
# - Решение:
#   - Удалить строки с критически важными пропусками (например, если нет ни даты, ни рейтинга, ни описания).
#
# ### **2. Приведение форматов к единому виду**
# - Преобразовать `release_date` в формат datetime
# - Создать столбец `release_year`
#    - ✅ это будет важная колонка для временного анализа, которая позволит изучать влияние временных факторов на популярность, бюджеты и жанры фильмов. `realease_date` не позволяет этого делать.
# - Оставить только фильмы, выпущенные до 1 января 2025 года
# - Столбцы `Rotten_Tomatoes`, `Metacritic`, `Metascore` — привести к числовому виду, удалив `%`, `N/A` и пр.
#
# ### **3. Очистка текстовых полей**
# - Удалить лишние пробелы, спецсимволы и единообразно привести регистр в `overview`, `title`, `director`, `genres`, `production_companies` и т.д.
# - Преобразовать строки, содержащие списки (например, `['James Cameron']`), в Python-списки:
# - Стандартизировать язык (`original_language`) и страну производства (`production_countries`).
#
#
# ### **4. Финансовые поля**
# - Преобразовать значения в `budget`, `revenue`, `profit`, `roi` в миллионы долларов:
#
#
# ### **5. Проверка дубликатов**
# - Найти дубликаты по `title` и `imdb_id`
#
# - - -

# %%
#  очистка всех переменных (не трогает ядро, не сбрасывает вывод)
from IPython import get_ipython
get_ipython().run_line_magic('reset', '-f')

# %%
import pandas as pd
import numpy as np
import ast
df_merged = pd.read_csv('data/raw/sci_fi_movies_merged.csv')

df_cleaned = df_merged.copy()  # создаем копию данных, чтобы не изменять оригинал
# Out:
# /var/folders/j1/p2qvyplx67lfm2kfmhw_tb700000gn/T/ipykernel_8417/665304916.py:4: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_merged = pd.read_csv('data/raw/sci_fi_movies_merged.csv')

# %% [markdown]
# #### 1. работа с пропущенными значениями

# %%
df_cleaned.dropna(subset=['release_date', 'overview', 'imdb_average'])
# Out:
#         Unnamed: 0      id                 title        original_title  \
# 0                0    2756             The Abyss             The Abyss
# 1                1     185    A Clockwork Orange    A Clockwork Orange
# 2                2  720321               Breathe               Breathe
# 3                3     871    Planet of the Apes    Planet of the Apes
# 4                4  760873            The Colony                 Tides
# ...            ...     ...                   ...                   ...
# 485852      485852  633225         Time of Sheep     A Era das Ovelhas
# 485853      485853  615076           Exposure 36           Exposure 36
# 485854      485854  604279    The Kids from 62-F    The Kids from 62-F
# 485855      485855  541526            Messengers            Messengers
# 485856      485856  537928  El satélite chiflado  El satélite chiflado
#
#                                                  overview release_date  \
# 0       A civilian oil rig crew is recruited to conduc...   1989-08-09
# 1       In a near-future Britain, young Alexander DeLa...   1971-12-19
# 2       Air-supply is scarce in the near future, forci...   2024-04-04
# 3       Astronaut Taylor crash lands on a distant plan...   1968-02-07
# 4       In the not-too-distant future: after a global ...   2021-08-26
# ...                                                   ...          ...
# 485852  Times are changing. A mysterious red dust has ...   2018-10-19
# 485853  A dejected young photographer, turned low leve...   2021-10-20
# 485854  A group of kids find classified information fr...   2016-02-24
# 485855  Dr. Sarah Chapel returns to the small town of ...   2004-06-27
# 485856  While on tour through Latin America, los Grand...   1956-07-10
#
#         popularity  imdb_average  imdb_count     imdb_id  ...  \
# 0             3.67          7.40        3082   tt0096754  ...
# 1             4.28          8.20       13078   tt0066921  ...
# 2             3.57          5.81         196  tt11540468  ...
# 3             4.09          7.60        3630   tt0063442  ...
# 4             3.65          5.70         290   tt6506264  ...
# ...            ...           ...         ...         ...  ...
# 485852        0.38          0.00           0   tt8779764  ...
# 485853        0.38          5.00           6  tt10518732  ...
# 485854        0.38          4.30           3   tt4172746  ...
# 485855        0.38          5.30           3   tt0347534  ...
# 485856        0.38          5.00           1   tt0198997  ...
#
#                                                  top_cast  \
# 0       ['Ed Harris', 'Mary Elizabeth Mastrantonio', '...
# 1       ['Malcolm McDowell', 'Patrick Magee', 'Carl Du...
# 2       ['Jennifer Hudson', 'Milla Jovovich', 'Quvenzh...
# 3       ['Charlton Heston', 'Roddy McDowall', 'Kim Hun...
# 4       ['Nora Arnezeder', 'Iain Glen', 'Sarah-Sofie B...
# ...                                                   ...
# 485852                                     ['Jorge Mota']
# 485853  ['Charles Ouda', 'Jennifer Leigh Whitehead', '...
# 485854  ['Gigi Cesarè', 'Eden McCoy', 'Will Spencer', ...
# 485855  ['Michele Hicks', 'Erik Jensen', 'Frankie Fais...
# 485856  ['Jorge Luz', 'Zelmar Gueñol', 'Guillermo Rico...
#
#                                            secondary_cast  \
# 0       ['John Bedford Lloyd', 'Kimberly Scott', 'Chri...
# 1       ['James Marcus', 'Michael Tarn', 'Miriam Karli...
# 2       ['Raúl Castillo', 'James Saito', 'Dan Martin',...
# 3       ['James Daly', 'Linda Harrison', 'Robert Gunne...
# 4       ['Joel Basman', 'Kotti Yun', 'Bella Bading', '...
# ...                                                   ...
# 485852                                                 []
# 485853  ['James David Rich', 'Montgomery Mauro', 'Chuc...
# 485854  ['April Marshall-Miller', 'Darius Marcell', 'R...
# 485855  ['Peter McRobbie', 'Ronald Guttman', 'John Car...
# 485856  ['Ethel Rojo', 'Raúl Arce', 'Carlos Bianquet',...
#
#                                             episodic_cast  \
# 0       ['J. Kenneth Campbell', 'Peter Ratray', 'Micha...
# 1       ['Michael Gover', 'Godfrey Quigley', 'Madge Ry...
# 2                                                      []
# 3       ['Martin Abrahams', 'Army Archerd', 'James Bac...
# 4                                                      []
# ...                                                   ...
# 485852                                                 []
# 485853                                                 []
# 485854                                                 []
# 485855  ['Elain R. Graham', 'Dan MacDonald', 'Wade Myl...
# 485856                                                 []
#
#                                                    Awards Rotten_Tomatoes  \
# 0              Won 1 Oscar. 9 wins & 16 nominations total             89%
# 1       Nominated for 4 Oscars. 12 wins & 26 nominatio...             86%
# 2                                                     NaN             14%
# 3       Nominated for 2 Oscars. 6 wins & 5 nominations...             86%
# 4                                 10 wins & 4 nominations             54%
# ...                                                   ...             ...
# 485852                                                NaN             NaN
# 485853                                              1 win             86%
# 485854                             4 wins & 2 nominations             NaN
# 485855                                             2 wins             NaN
# 485856                                                NaN             NaN
#
#         Metacritic  Metascore  wins nominations awards_type
# 0            89.00        NaN     1           0       Oscar
# 1            86.00        NaN     0           4       Oscar
# 2            14.00        NaN     0           0     No data
# 3            86.00        NaN     0           2       Oscar
# 4            54.00        NaN     0           0       Other
# ...            ...        ...   ...         ...         ...
# 485852         NaN        NaN     0           0     No data
# 485853       86.00        NaN     0           0       Other
# 485854         NaN        NaN     0           0       Other
# 485855         NaN        NaN     0           0       Other
# 485856         NaN        NaN     0           0     No data
#
# [372409 rows x 34 columns]

# %% [markdown]
# #### 2. приведение форматов к единому виду
#
# приводим дату релиза к datetime, извлекаем год и фильтруем по дате. также обработаем числовые рейтинги.

# %%
# дата релиза
df_cleaned['release_date'] = pd.to_datetime(df_cleaned['release_date'], errors='coerce')

# извлекаем год релиза
df_cleaned['release_year'] = df_cleaned['release_date'].dt.year

# фильтрация по дате — только до 2025 года
df_cleaned = df_cleaned[df_cleaned['release_date'] <= '2025-01-01']

# очищаем проценты и 'N/A', преобразуем в числовой формат
df_cleaned['Rotten_Tomatoes'] = df_cleaned['Rotten_Tomatoes'].str.replace('%', '', regex=False)
df_cleaned['Rotten_Tomatoes'] = pd.to_numeric(df_cleaned['Rotten_Tomatoes'], errors='coerce')

df_cleaned['Metacritic'] = pd.to_numeric(df_cleaned['Metacritic'], errors='coerce')
df_cleaned['Metascore'] = pd.to_numeric(df_cleaned['Metascore'], errors='coerce')

# %% [markdown]
# #### 3. очистка текстовых полей
#
# удаляем лишние пробелы в строках, безопасно парсим поля со списками (если они сохранены в строковом виде)
# и стандартизируем язык и страны в нижний регистр. при этом названия фильмов и оригинальные названия приводим к нормальному виду.

# %%
import ast
import re

# очищаем пробелы в строках, не меняя регистр
text_columns = ['title', 'original_title', 'overview']
for col in text_columns:
    df_cleaned[col] = df_cleaned[col].apply(lambda x: x.strip() if isinstance(x, str) else x)

# функция безопасного преобразования строки в список
def safe_parse_list(text):
    if isinstance(text, list):
        return text
    if isinstance(text, str) and text.startswith('['):
        try:
            return ast.literal_eval(text)
        except:
            # если кавычек нет, но элементы разделены запятыми
            return [item.strip() for item in re.sub(r'[\[\]]', '', text).split(',') if item.strip()]
    return []

# обрабатываем поля со списками
list_columns = [
    'director', 'writer', 'producer', 'genres', 'production_countries',
    'full_cast', 'top_cast', 'secondary_cast', 'episodic_cast'
]

for col in list_columns:
    df_cleaned[col] = df_cleaned[col].apply(safe_parse_list)

# %% [markdown]
# #### 4. финансовые поля
#
# преобразуем денежные столбцы в миллионы долларов

# %%
# пересчитываем прибыль до перевода в миллионы долларов
df_cleaned['profit'] = df_cleaned['revenue'] - df_cleaned['budget']

# делим бюджет, выручку и прибыль на миллион для удобства восприятия
money_columns = ['budget', 'revenue', 'profit']
df_cleaned[money_columns] = df_cleaned[money_columns] / 1e6

pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# #### 5. проверка дубликатов
#
# ищем дубликаты по названию и imdb_id

# %%
# Находим дубли по столбцам 'title' и 'imdb_id'
duplicates = df_cleaned[df_cleaned.duplicated(subset=['title', 'imdb_id'], keep='first')]

# Удаляем дубли
df_cleaned = df_cleaned.drop_duplicates(subset=['title', 'imdb_id'], keep='first')

# %%
df_cleaned.info()  #проводим осмотр таблицы
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9369 entries, 0 to 485856
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            9369 non-null   int64
#  1   id                    9369 non-null   int64
#  2   title                 9369 non-null   object
#  3   original_title        9369 non-null   object
#  4   overview              9196 non-null   object
#  5   release_date          9369 non-null   datetime64[ns]
#  6   popularity            9369 non-null   float64
#  7   imdb_average          9369 non-null   float64
#  8   imdb_count            9369 non-null   int64
#  9   imdb_id               8809 non-null   object
#  10  director              9369 non-null   object
#  11  producer              9369 non-null   object
#  12  writer                9369 non-null   object
#  13  editor                9369 non-null   object
#  14  cinematographer       9369 non-null   object
#  15  budget                9369 non-null   float64
#  16  revenue               9369 non-null   float64
#  17  runtime               9369 non-null   int64
#  18  tagline               4887 non-null   object
#  19  production_countries  9369 non-null   object
#  20  original_language     9369 non-null   object
#  21  production_companies  9369 non-null   object
#  22  genres                9369 non-null   object
#  23  full_cast             9369 non-null   object
#  24  top_cast              9369 non-null   object
#  25  secondary_cast        9369 non-null   object
#  26  episodic_cast         9369 non-null   object
#  27  Awards                5227 non-null   object
#  28  Rotten_Tomatoes       2000 non-null   float64
#  29  Metacritic            2000 non-null   float64
#  30  Metascore             0 non-null      float64
#  31  wins                  9369 non-null   int64
#  32  nominations           9369 non-null   int64
#  33  awards_type           9369 non-null   object
#  34  release_year          9369 non-null   float64
#  35  profit                9369 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(6), object(20)
# memory usage: 2.6+ MB

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0      id               title      original_title  \
# 0           0    2756           The Abyss           The Abyss
# 1           1     185  A Clockwork Orange  A Clockwork Orange
# 2           2  720321             Breathe             Breathe
# 3           3     871  Planet of the Apes  Planet of the Apes
# 4           4  760873          The Colony               Tides
#
#                                             overview release_date  popularity  \
# 0  A civilian oil rig crew is recruited to conduc...   1989-08-09        3.67
# 1  In a near-future Britain, young Alexander DeLa...   1971-12-19        4.28
# 2  Air-supply is scarce in the near future, forci...   2024-04-04        3.57
# 3  Astronaut Taylor crash lands on a distant plan...   1968-02-07        4.09
# 4  In the not-too-distant future: after a global ...   2021-08-26        3.65
#
#    imdb_average  imdb_count     imdb_id  ...  \
# 0          7.40        3082   tt0096754  ...
# 1          8.20       13078   tt0066921  ...
# 2          5.81         196  tt11540468  ...
# 3          7.60        3630   tt0063442  ...
# 4          5.70         290   tt6506264  ...
#
#                                        episodic_cast  \
# 0  [J. Kenneth Campbell, Peter Ratray, Michael Be...
# 1  [Michael Gover, Godfrey Quigley, Madge Ryan, A...
# 2                                                 []
# 3  [Martin Abrahams, Army Archerd, James Bacon, E...
# 4                                                 []
#
#                                               Awards Rotten_Tomatoes  \
# 0         Won 1 Oscar. 9 wins & 16 nominations total           89.00
# 1  Nominated for 4 Oscars. 12 wins & 26 nominatio...           86.00
# 2                                                NaN           14.00
# 3  Nominated for 2 Oscars. 6 wins & 5 nominations...           86.00
# 4                            10 wins & 4 nominations           54.00
#
#   Metacritic Metascore  wins  nominations  awards_type release_year profit
# 0      89.00       NaN     1            0        Oscar     1,989.00  20.00
# 1      86.00       NaN     0            4        Oscar     1,971.00  24.83
# 2      14.00       NaN     0            0      No data     2,024.00   0.00
# 3      86.00       NaN     0            2        Oscar     1,968.00  26.79
# 4      54.00       NaN     0            0        Other     2,021.00   0.33
#
# [5 rows x 36 columns]

# %%
## обнаруживаем, что образовалась лишняя колонка Unnamed, а Metacritic и Metascore не несут никакой информации
# удаяем ненужные колонки
df_cleaned = df_cleaned.drop(columns=['Metacritic', 'Metascore', 'Unnamed: 0'])

# %%
df_cleaned.to_csv('data/clean/sci_fi_movies_cleaned.csv')

# %% [markdown]
# ---
#
# ## **Итог**
#
# Обновлённый датасет полностью готов к EDA:
# - Все ключевые поля имеют корректные типы
# - Критические пропуски устранены
# - Псевдосписки заменены на настоящие массивы
# - Добавлен признак года релиза
